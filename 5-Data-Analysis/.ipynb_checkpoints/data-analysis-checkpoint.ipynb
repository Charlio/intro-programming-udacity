# %%
import pandas as pd
from matplotlib import pyplot as plt

# %matplotlib inline

# %%
data = pd.read_csv("tmdb-movies.csv")

# %% [markdown]
# ### The following questions will be answered
# - Which directors have the highest number of movies?
# - What is the distribution of runtime?
# - Which year has the highest number of movies?
# - How many movies have a higher revenue_adj than budget_adj?
# - Which genres are the most popular?

# %%
data.columns
# Out:
# Index(['id', 'imdb_id', 'popularity', 'budget', 'revenue', 'original_title',
#        'cast', 'homepage', 'director', 'tagline', 'keywords', 'overview',
#        'runtime', 'genres', 'production_companies', 'release_date',
#        'vote_count', 'vote_average', 'release_year', 'budget_adj',
#        'revenue_adj'],
#       dtype='object')

# %%
# only the following columns will be considered in this analysis

reduced_columns = [
    u'popularity', 
    u'original_title', 
    u'director',
    u'runtime', 
    u'genres',
    u'release_date', 
    u'vote_count',
    u'vote_average', 
    u'release_year', 
    u'budget_adj', 
    u'revenue_adj',
]

data = data[reduced_columns]

# %%
data.head()
# Out:
#    popularity                original_title          director  runtime  \
# 0   32.985763                Jurassic World   Colin Trevorrow      124
# 1   28.419936            Mad Max: Fury Road     George Miller      120
# 2   13.112507                     Insurgent  Robert Schwentke      119
# 3   11.173104  Star Wars: The Force Awakens       J.J. Abrams      136
# 4    9.335014                     Furious 7         James Wan      137
#
#                                       genres release_date  vote_count  \
# 0  Action|Adventure|Science Fiction|Thriller       6/9/15        5562
# 1  Action|Adventure|Science Fiction|Thriller      5/13/15        6185
# 2         Adventure|Science Fiction|Thriller      3/18/15        2480
# 3   Action|Adventure|Science Fiction|Fantasy     12/15/15        5292
# 4                      Action|Crime|Thriller       4/1/15        2947
#
#    vote_average  release_year    budget_adj   revenue_adj
# 0           6.5          2015  1.379999e+08  1.392446e+09
# 1           7.1          2015  1.379999e+08  3.481613e+08
# 2           6.3          2015  1.012000e+08  2.716190e+08
# 3           7.5          2015  1.839999e+08  1.902723e+09
# 4           7.3          2015  1.747999e+08  1.385749e+09

# %%
data.describe()
# Out:
#          popularity       runtime    vote_count  vote_average  release_year  \
# count  10866.000000  10866.000000  10866.000000  10866.000000  10866.000000
# mean       0.646441    102.070863    217.389748      5.974922   2001.322658
# std        1.000185     31.381405    575.619058      0.935142     12.812941
# min        0.000065      0.000000     10.000000      1.500000   1960.000000
# 25%        0.207583     90.000000     17.000000      5.400000   1995.000000
# 50%        0.383856     99.000000     38.000000      6.000000   2006.000000
# 75%        0.713817    111.000000    145.750000      6.600000   2011.000000
# max       32.985763    900.000000   9767.000000      9.200000   2015.000000
#
#          budget_adj   revenue_adj
# count  1.086600e+04  1.086600e+04
# mean   1.755104e+07  5.136436e+07
# std    3.430616e+07  1.446325e+08
# min    0.000000e+00  0.000000e+00
# 25%    0.000000e+00  0.000000e+00
# 50%    0.000000e+00  0.000000e+00
# 75%    2.085325e+07  3.369710e+07
# max    4.250000e+08  2.827124e+09

# %% [markdown]
# ### Which directors have the highest number of movies?

# %%
count_by_directors = data.groupby(["director"]).size()
count_by_directors.hist(bins=50)

# %%
count_by_directors.sort_values(ascending=False)[:10]
# Out:
# director
# Woody Allen          45
# Clint Eastwood       34
# Steven Spielberg     29
# Martin Scorsese      29
# Ridley Scott         23
# Steven Soderbergh    22
# Ron Howard           22
# Joel Schumacher      21
# Brian De Palma       20
# Wes Craven           19
# dtype: int64

# %% [markdown]
# ### What is the distribution of runtime?

# %%
data['runtime'].hist(bins=100)
data['runtime'].describe()
# Out:
# count    10866.000000
# mean       102.070863
# std         31.381405
# min          0.000000
# 25%         90.000000
# 50%         99.000000
# 75%        111.000000
# max        900.000000
# Name: runtime, dtype: float64

# %% [markdown]
# The longest movie is a documentary:

# %%
data[data['runtime'] == 900]
# Out:
#       popularity                 original_title      director  runtime  \
# 3894    0.006925  The Story of Film: An Odyssey  Mark Cousins      900
#
#            genres release_date  vote_count  vote_average  release_year  \
# 3894  Documentary       9/3/11          14           9.2          2011
#
#       budget_adj  revenue_adj
# 3894         0.0          0.0

# %% [markdown]
# The dataset contains several movies with 0 runtime, all of them have zero budget and revenue:

# %%
data[data['runtime'] == 0]
# Out:
#       popularity                 original_title  \
# 92      1.876037       Mythica: The Necromancer
# 334     0.357654                        Ronaldo
# 410     0.097514                 Anarchy Parlor
# 445     0.218528  The Exorcism of Molly Hartley
# 486     0.176744             If There Be Thorns
# 595     0.028725                      Deep Dark
# 616     0.026797                   The Outfield
# 1241    0.135376                      Dance-Off
# 1289    0.037459                      Treehouse
# 1293    0.036904                       Tim Maia
# 1849    0.120350                   Spectacular!
# 2315    0.171615           Listen to Your Heart
# 2370    0.081892                Freshman Father
# 3329    0.082898       Grande, grosso e Verdone
# 3794    0.183134           Toi, moi, les autres
# 3857    0.095583                       Cell 213
# 3884    0.045198                         eCupid
# 4063    0.371510         Madea's Family Reunion
# 4138    0.035895             A Time for Dancing
# 4829    0.140016                           Rags
# 4944    0.026459            How to Fall in Love
# 5216    0.073665          Madea's Class Reunion
# 5695    0.417739               Skinwalker Ranch
# 5920    0.165765         The Food Guide to Love
# 5938    0.147188                    Go Goa Gone
# 5992    0.096455               Amiche da morire
# 6040    0.011798          The Vatican Exorcisms
# 6383    0.371630       The 12 Dogs of Christmas
# 6552    0.006440                Quatre ̩toiles
# 6934    0.071872                  Jean-Philippe
# 8874    0.069903                Mission Kashmir
#
#                            director  runtime                           genres  \
# 92                    A. Todd Smith        0         Fantasy|Action|Adventure
# 334                   Anthony Wonke        0                      Documentary
# 410          Kenny Gage|Devon Downs        0                           Horror
# 445                Steven R. Monroe        0                           Horror
# 486                    Nancy Savoca        0                   TV Movie|Drama
# 595                Michael Medaglia        0                           Horror
# 616                Michael Goldfine        0                     Drama|Comedy
# 1241                            NaN        0             Romance|Music|Comedy
# 1289            Michael G. Bartlett        0          Thriller|Horror|Mystery
# 1293                     Mauro Lima        0          Documentary|Drama|Music
# 1849                  Robert Iscove        0                      Drama|Music
# 2315                            NaN        0              Drama|Music|Romance
# 2370                  Michael Scott        0                              NaN
# 3329                  Carlo Verdone        0                           Family
# 3794                Audrey Estrougo        0                    Music|Romance
# 3857                    Stephen Kay        0                           Horror
# 3884                  J.C. Calciano        0                          Romance
# 4063                    Tyler Perry        0                           Comedy
# 4138                  Peter Gilbert        0                      Drama|Music
# 4829                 Bille Woodruff        0            TV Movie|Comedy|Drama
# 4944                 Mark Griffiths        0          Comedy|Romance|TV Movie
# 5216                    Tyler Perry        0                     Comedy|Music
# 5695                   Devin McGinn        0  Thriller|Horror|Science Fiction
# 5920  Dominic Harari|Teresa Pelegri        0                   Romance|Comedy
# 5938      Krishna D.K.|Raj Nidimoru        0                    Comedy|Horror
# 5992                 Giorgia Farina        0             Romance|Crime|Comedy
# 6040                     Joe Marino        0       Horror|Documentary|Mystery
# 6383                  Kieth Merrill        0                     Drama|Family
# 6552              Christian Vincent        0                           Comedy
# 6934                   Laurent Tuel        0                           Comedy
# 8874             Vidhu Vinod Chopra        0             Action|Drama|Foreign
#
#      release_date  vote_count  vote_average  release_year    budget_adj  \
# 92       12/19/15          11           5.4          2015  0.000000e+00
# 334       11/9/15          80           6.5          2015  0.000000e+00
# 410        1/1/15          15           5.6          2015  0.000000e+00
# 445       10/9/15          52           5.0          2015  0.000000e+00
# 486        4/5/15          11           5.4          2015  0.000000e+00
# 595        1/1/15          11           4.6          2015  0.000000e+00
# 616      11/10/15          20           6.6          2015  0.000000e+00
# 1241       1/1/14          18           5.7          2014  0.000000e+00
# 1289     10/20/14          16           3.4          2014  2.993546e+06
# 1293     10/30/14          14           6.0          2014  0.000000e+00
# 1849      2/16/09          13           5.2          2009  0.000000e+00
# 2315      8/14/10          29           7.3          2010  0.000000e+00
# 2370       6/5/10          12           5.8          2010  0.000000e+00
# 3329       3/7/08          35           5.3          2008  0.000000e+00
# 3794      2/22/11          17           5.2          2011  0.000000e+00
# 3857      6/10/11          13           5.2          2011  0.000000e+00
# 3884      6/23/11          12           4.6          2011  0.000000e+00
# 4063      1/25/02          49           5.9          2002  7.273568e+06
# 4138       9/6/02          14           7.5          2002  0.000000e+00
# 4829      5/28/12          24           5.7          2012  0.000000e+00
# 4944      7/21/12          11           4.7          2012  0.000000e+00
# 5216      6/25/03          12           6.9          2003  0.000000e+00
# 5695     10/30/13          27           4.3          2013  0.000000e+00
# 5920     12/18/13          12           5.6          2013  0.000000e+00
# 5938      5/10/13          16           5.3          2013  0.000000e+00
# 5992       3/7/13          30           5.5          2013  0.000000e+00
# 6040      5/29/13          10           4.7          2013  0.000000e+00
# 6383      11/1/05          11           4.7          2005  2.233127e+06
# 6552       1/1/05          15           5.9          2005  0.000000e+00
# 6934       4/5/06          26           5.6          2006  0.000000e+00
# 8874     10/27/00          10           5.7          2000  0.000000e+00
#
#       revenue_adj
# 92            0.0
# 334           0.0
# 410           0.0
# 445           0.0
# 486           0.0
# 595           0.0
# 616           0.0
# 1241          0.0
# 1289          0.0
# 1293          0.0
# 1849          0.0
# 2315          0.0
# 2370          0.0
# 3329          0.0
# 3794          0.0
# 3857          0.0
# 3884          0.0
# 4063          0.0
# 4138          0.0
# 4829          0.0
# 4944          0.0
# 5216          0.0
# 5695          0.0
# 5920          0.0
# 5938          0.0
# 5992          0.0
# 6040          0.0
# 6383          0.0
# 6552          0.0
# 6934          0.0
# 8874          0.0

# %% [markdown]
# ### - Which year has the highest number of movies?

# %% [markdown]
# The amount of movies increases exponentially

# %%
count_by_years = data.groupby(["release_year"]).size()
count_by_years.plot()

# %%
count_by_years.sort_values(ascending=False)[:10]
# Out:
# release_year
# 2014    700
# 2013    659
# 2015    629
# 2012    588
# 2011    540
# 2009    533
# 2008    496
# 2010    490
# 2007    438
# 2006    408
# dtype: int64

# %% [markdown]
# ### How many movies have a higher revenue_adj than budget_adj?

# %%
profitable = data[data['revenue_adj'] > data['budget_adj']]

# %% [markdown]
# Only one third of all the movies make profit:

# %%
print(len(profitable)) 
print(len(profitable)/len(data))
# Out:
# 3773
# 0.34722989140438065

# %% [markdown]
# ### Which genres are the most popular?

# %%
from collections import Counter
genres = Counter()
genre_series = data["genres"].dropna()
for genre in genre_series:
    cur_genres = genre.split('|')
    for cur_genre in cur_genres:
        genres[cur_genre] += 1
genres.most_common()
# Out:
# [('Drama', 4761),
#  ('Comedy', 3793),
#  ('Thriller', 2908),
#  ('Action', 2385),
#  ('Romance', 1712),
#  ('Horror', 1637),
#  ('Adventure', 1471),
#  ('Crime', 1355),
#  ('Family', 1231),
#  ('Science Fiction', 1230),
#  ('Fantasy', 916),
#  ('Mystery', 810),
#  ('Animation', 699),
#  ('Documentary', 520),
#  ('Music', 408),
#  ('History', 334),
#  ('War', 270),
#  ('Foreign', 188),
#  ('TV Movie', 167),
#  ('Western', 165)]
